# %%
import pandas as pd

# %%
food_data = pd.read_csv("https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding = "latin-1")

# %%
food_data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
# Question 1 (2015)
food_data.groupby("Item")['Y2015'].sum()
# Out:
# Item
# Alcohol, Non-Food        2180.00
# Alcoholic Beverages     98783.72
# Animal Products         11811.73
# Animal fats            200675.72
# Apples and products     10559.15
#                          ...
# Vegetables, Other      158104.08
# Vegetal Products       107064.17
# Wheat and products     234710.51
# Wine                     4251.81
# Yams                   203151.78
# Name: Y2015, Length: 119, dtype: float64

# %%
# Question 1(2018)
food_data.groupby("Item")['Y2018'].sum()
# Out:
# Item
# Alcohol, Non-Food        2293.00
# Alcoholic Beverages     97847.27
# Animal Products         11578.61
# Animal fats            269648.27
# Apples and products      9640.51
#                          ...
# Vegetables, Other      163987.21
# Vegetal Products       107775.39
# Wheat and products     242645.19
# Wine                     4039.32
# Yams                   221272.09
# Name: Y2018, Length: 119, dtype: float64

# %%
# Question 2 (Missing values in Y2014)
round(food_data['Y2014'].isnull().sum(), 3)
# Out:
# 1589

# %%
# Question 2 (Percentage missing values in Y2014)
round(100 * food_data['Y2014'].isnull().sum()/food_data['Y2014'].count(),3)
# Out:
# 2.677

# %%
# Question 3
food_data.groupby('Area')['Y2017'].sum().sort_values()[:7]
# Out:
# Area
# Sudan (former)               0.00
# Ethiopia PDR                 0.00
# Comoros                     59.84
# Seychelles                 442.34
# Sao Tome and Principe    12662.63
# Cabo Verde               14650.74
# Guinea-Bissau            19102.77
# Name: Y2017, dtype: float64

# %%
# Question 4
food_data["Area"].nunique()
# Out:
# 49

# %%
# Question 6
food_data.groupby("Element")[["Y2014","Y2015","Y2016","Y2017","Y2018"]].sum()
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %%
# Question 9
mask = food_data[["Element","Area","Y2015"]]
mask = mask[(mask["Element"] == "Protein supply quantity (g/capita/day)") & (mask["Area"] == "Madagascar")]
mask["Y2015"].sum()
# Out:
# 173.04999999999998

# %%
# Question 11
food_data["Y2017"].describe()
# Out:
# count     59437.000000
# mean        140.917765
# std        1671.862359
# min       -1582.000000
# 25%           0.000000
# 50%           0.100000
# 75%           9.000000
# max      190873.000000
# Name: Y2017, dtype: float64

# %%
# Question 12
food_data.groupby("Element").sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
# Question 14
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
col = ['Age','Nationality','Overall']
pd.DataFrame(lst, columns = col, index = [1,2,3])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
# Question 15
food_data.corr().min()
# Out:
# Area Code      -0.005159
# Item Code      -0.024683
# Element Code   -0.024683
# Y2014           0.006164
# Y2015           0.005472
# Y2016           0.005247
# Y2017           0.005006
# Y2018           0.005665
# dtype: float64

# %%
# Question 17
food_data.groupby("Area")["Y2017"].sum().sort_values(ascending=False)[:1]
# Out:
# Area
# Nigeria    1483268.23
# Name: Y2017, dtype: float64

# %%
# Question 18
my_tuppy = (1,2,5,8)
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\HP\Downloads\My Data Science Projects\assignment\stageA.ipynb Cell 17 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/My%20Data%20Science%20Projects/assignment/stageA.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> # Question 18
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/My%20Data%20Science%20Projects/assignment/stageA.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> my_tuppy = (1,2,5,8)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/My%20Data%20Science%20Projects/assignment/stageA.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Question 19
y = [(2, 4), (7, 8), (1, 5, 9)]
x = y[1][1]
print(x)
x = y[1][-1]
x
# Out:
# 8
# 8
